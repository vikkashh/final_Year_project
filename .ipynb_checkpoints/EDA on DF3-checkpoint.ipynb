# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("DF3_Magnitude.xlsx")

# %%
df.head()
# Out:
#      M1_min    M1_max   M1_mean    M1_std        M1_var    M1_rms    M1_mav  \
# 0  0.000263  0.000752  0.000502  0.000067  4.551717e-09  0.000506  0.000502
# 1  0.000239  0.000744  0.000500  0.000067  4.554403e-09  0.000505  0.000500
# 2  0.000256  0.000755  0.000503  0.000067  4.524080e-09  0.000507  0.000503
# 3  0.000257  0.000756  0.000505  0.000067  4.527095e-09  0.000509  0.000505
# 4  0.000252  0.000755  0.000506  0.000067  4.500827e-09  0.000510  0.000506
#
#      M2_min    M2_max   M2_mean  ...    M8_max   M8_mean   M8_std  \
# 0  0.000166  0.000470  0.000317  ...  0.000339  0.000219  0.00003
# 1  0.000163  0.000482  0.000317  ...  0.000342  0.000220  0.00003
# 2  0.000156  0.000476  0.000318  ...  0.000344  0.000213  0.00003
# 3  0.000157  0.000470  0.000316  ...  0.000334  0.000215  0.00003
# 4  0.000155  0.000478  0.000315  ...  0.000347  0.000217  0.00003
#
#          M8_var    M8_rms    M8_mav  Amplitude  Condition  Level  \
# 0  9.185403e-10  0.000221  0.000219        0.5        6Nm      1
# 1  9.203908e-10  0.000222  0.000220        0.5        6Nm      1
# 2  9.204369e-10  0.000215  0.000213        0.5        6Nm      1
# 3  9.161455e-10  0.000217  0.000215        0.5        6Nm      1
# 4  9.012421e-10  0.000219  0.000217        0.5        6Nm      1
#
#                FileName
# 0  0.5amp-6Nm-lev1-EXP1
# 1  0.5amp-6Nm-lev1-EXP2
# 2  0.5amp-6Nm-lev1-EXP3
# 3  0.5amp-6Nm-lev1-EXP4
# 4  0.5amp-6Nm-lev1-EXP5
#
# [5 rows x 60 columns]

# %%
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
# Out:
# (273, 60)
# Index(['M1_min', 'M1_max', 'M1_mean', 'M1_std', 'M1_var', 'M1_rms', 'M1_mav',
#        'M2_min', 'M2_max', 'M2_mean', 'M2_std', 'M2_var', 'M2_rms', 'M2_mav',
#        'M3_min', 'M3_max', 'M3_mean', 'M3_std', 'M3_var', 'M3_rms', 'M3_mav',
#        'M4_min', 'M4_max', 'M4_mean', 'M4_std', 'M4_var', 'M4_rms', 'M4_mav',
#        'M5_min', 'M5_max', 'M5_mean', 'M5_std', 'M5_var', 'M5_rms', 'M5_mav',
#        'M6_min', 'M6_max', 'M6_mean', 'M6_std', 'M6_var', 'M6_rms', 'M6_mav',
#        'M7_min', 'M7_max', 'M7_mean', 'M7_std', 'M7_var', 'M7_rms', 'M7_mav',
#        'M8_min', 'M8_max', 'M8_mean', 'M8_std', 'M8_var', 'M8_rms', 'M8_mav',
#        'Amplitude', 'Condition', 'Level', 'FileName'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 273 entries, 0 to 272
# Data columns (total 60 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   M1_min     273 non-null    float64
#  1   M1_max     273 non-null    float64
#  2   M1_mean    273 non-null    float64
#  3   M1_std     273 non-null    float64
#  4   M1_var     273 non-null    float64
#  5   M1_rms     273 non-null    float64
#  6   M1_mav     273 non-null    float64
#  7   M2_min     273 non-null    float64
#  8   M2_max     273 non-null    float64
#  9   M2_mean    273 non-null    float64
#  10  M2_std     273 non-null    float64
#  11  M2_var     273 non-null    float64
#  12  M2_rms     273 non-null    float64
#  13  M2_mav     273 non-null    float64
#  14  M3_min     273 non-null    float64
#  15  M3_max     273 non-null    float64
#  16  M3_mean    273 non-null    float64
#  17  M3_std     273 non-null    float64
#  18  M3_var     273 non-null    float64
#  19  M3_rms     273 non-null    float64
#  20  M3_mav     273 non-null    float64
#  21  M4_min     273 non-null    float64
#  22  M4_max     273 non-null    float64
#  23  M4_mean    273 non-null    float64
#  24  M4_std     273 non-null    float64
#  25  M4_var     273 non-null    float64
#  26  M4_rms     273 non-null    float64
#  27  M4_mav     273 non-null    float64
#  28  M5_min     273 non-null    float64
#  29  M5_max     273 non-null    float64
#  30  M5_mean    273 non-null    float64
#  31  M5_std     273 non-null    float64
#  32  M5_var     273 non-null    float64
#  33  M5_rms     273 non-null    float64
#  34  M5_mav     273 non-null    float64
#  35  M6_min     273 non-null    float64
#  36  M6_max     273 non-null    float64
#  37  M6_mean    273 non-null    float64
#  38  M6_std     273 non-null    float64
#  39  M6_var     273 non-null    float64
#  40  M6_rms     273 non-null    float64
#  41  M6_mav     273 non-null    float64
#  42  M7_min     273 non-null    float64
#  43  M7_max     273 non-null    float64
#  44  M7_mean    273 non-null    float64
#  45  M7_std     273 non-null    float64
#  46  M7_var     273 non-null    float64
#  47  M7_rms     273 non-null    float64
#  48  M7_mav     273 non-null    float64
#  49  M8_min     273 non-null    float64
#  50  M8_max     273 non-null    float64
#  51  M8_mean    273 non-null    float64
#  52  M8_std     273 non-null    float64
#  53  M8_var     273 non-null    float64
#  54  M8_rms     273 non-null    float64
#  55  M8_mav     273 non-null    float64
#  56  Amplitude  273 non-null    float64
#  57  Condition  273 non-null    object
#  58  Level      273 non-null    int64
#  59  FileName   273 non-null    object
# dtypes: float64(57), int64(1), object(2)
# memory usage: 128.1+ KB
# None
#            M1_min      M1_max     M1_mean      M1_std        M1_var  \
# count  273.000000  273.000000  273.000000  273.000000  2.730000e+02
# mean     0.000097    0.001169    0.000522    0.000147  2.525503e-08
# std      0.000102    0.000342    0.000036    0.000060  1.613686e-08
# min      0.000002    0.000640    0.000411    0.000065  4.182371e-09
# 25%      0.000017    0.000753    0.000501    0.000068  4.597877e-09
# 50%      0.000034    0.001228    0.000526    0.000165  2.719999e-08
# 75%      0.000214    0.001499    0.000554    0.000201  4.055784e-08
# max      0.000288    0.001745    0.000594    0.000224  5.035012e-08
#
#            M1_rms      M1_mav      M2_min      M2_max     M2_mean  ...  \
# count  273.000000  273.000000  273.000000  273.000000  273.000000  ...
# mean     0.000545    0.000522    0.000096    0.000596    0.000327  ...
# std      0.000047    0.000036    0.000062    0.000114    0.000010  ...
# min      0.000416    0.000411    0.000006    0.000452    0.000306  ...
# 25%      0.000512    0.000501    0.000019    0.000479    0.000320  ...
# 50%      0.000551    0.000526    0.000109    0.000572    0.000327  ...
# 75%      0.000590    0.000554    0.000156    0.000724    0.000334  ...
# max      0.000632    0.000594    0.000194    0.000828    0.000354  ...
#
#            M7_mav      M8_min      M8_max     M8_mean      M8_std  \
# count  273.000000  273.000000  273.000000  273.000000  273.000000
# mean     0.000341    0.000048    0.000441    0.000221    0.000050
# std      0.000017    0.000034    0.000097    0.000010    0.000017
# min      0.000297    0.000002    0.000320    0.000196    0.000027
# 25%      0.000333    0.000011    0.000345    0.000216    0.000031
# 50%      0.000346    0.000051    0.000416    0.000221    0.000047
# 75%      0.000352    0.000073    0.000541    0.000228    0.000067
# max      0.000376    0.000115    0.000701    0.000259    0.000097
#
#              M8_var      M8_rms      M8_mav   Amplitude       Level
# count  2.730000e+02  273.000000  273.000000  273.000000  273.000000
# mean   2.782397e-09    0.000227    0.000221    1.166667    2.307692
# std    1.845507e-09    0.000012    0.000010    0.624755    1.266296
# min    7.066087e-10    0.000198    0.000196    0.500000    0.000000
# 25%    9.440742e-10    0.000221    0.000216    0.500000    1.000000
# 50%    2.220676e-09    0.000227    0.000221    1.000000    2.000000
# 75%    4.531649e-09    0.000235    0.000228    2.000000    3.000000
# max    9.443303e-09    0.000277    0.000259    2.000000    4.000000
#
# [8 rows x 58 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x="Amplitude", y="M1_rms", data=df)
plt.title("Amplitude vs Vibration")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x="Amplitude", y="M1_rms", hue="Condition")
plt.title("Amplitude vs Vibration (RMS)")
plt.grid()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x="Amplitude", y="M1_mav", hue="Condition")
plt.title("Amplitude vs Vibration (RMS)")
plt.grid()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.scatterplot(data=df, x="Amplitude", y="M1_rms", hue="Level")
plt.title("Amplitude vs Vibration (RMS)")
plt.grid()
plt.show()

# %%
rms_cols = [col for col in df.columns if "_rms" in col]
df["Avg_RMS"] = df[rms_cols].mean(axis=1)

# %%
def to_nm(cond):
    if cond == "Healthy":
        return 12
    elif "9" in cond:
        return 9
    elif "6" in cond:
        return 6
    else:
        return 0

df["Bolt_Nm"] = df["Condition"].apply(to_nm)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.lineplot(data=df, x="Amplitude", y="Avg_RMS", estimator="mean", marker="o")
plt.title("Amplitude vs Vibration (RMS)")
plt.show()

# %%
sns.lineplot(data=df, x="Bolt_Nm", y="Avg_RMS", estimator="mean", marker="o")
plt.title("Bolt Tightness vs Vibration")
plt.show()

# %%
sns.lineplot(data=df, x="Amplitude", y="Avg_RMS", hue="Condition", marker="o")
plt.title("Amplitude vs Vibration under Different Bolt Conditions")
plt.show()

# %%
sns.boxplot(x="Condition", y="Avg_RMS", data=df)
plt.title("Vibration Distribution by Condition")
plt.show()

# %%
sns.scatterplot(data=df, x="Amplitude", y="Avg_RMS", hue="Condition")
plt.title("Scatter: Amplitude vs Vibration")
plt.show()

# %%
corr = df.corr(numeric_only=True)

import seaborn as sns
sns.heatmap(corr, cmap="coolwarm")
plt.title("Feature Correlation")
plt.show()

# %%
plt.figure(figsize=(6,4))

sns.boxplot(data=df, x="Level", y="Avg_RMS")

plt.title("Level vs Vibration")
plt.xlabel("Damage Level")
plt.ylabel("Avg RMS")
plt.grid()

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(data=df, x="Level", y="Avg_RMS", hue="Condition")

plt.title("Level-wise Vibration by Bolt Condition")
plt.grid()

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.lineplot(data=df, x="Level", y="Avg_RMS", hue="Amplitude", marker="o")

plt.title("Level vs Vibration (by Amplitude)")
plt.grid()

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

max_cols = [col for col in df.columns if "_max" in col]

for col in max_cols:
    plt.figure(figsize=(5,3))
    
    sns.scatterplot(data=df, x="Amplitude", y=col)
    
    plt.title(f"{col} vs Amplitude")
    plt.xlabel("Amplitude")
    plt.ylabel(col)
    plt.grid()
    
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

max_cols = [col for col in df.columns if "_max" in col]

for col in max_cols:
    plt.figure(figsize=(6,4))

    sns.scatterplot(
        data=df,
        x="Amplitude",
        y=col,
        hue="Level"   # 👈 important change
    )

    plt.title(f"{col} vs Amplitude (Level-wise)")
    plt.xlabel("Amplitude")
    plt.ylabel(col)
    plt.grid()

    plt.show()

# %%
def to_nm(cond):
    if cond == "Healthy":
        return 12
    elif "9" in cond:
        return 9
    elif "6" in cond:
        return 6
    else:
        return 0

df["Bolt_Nm"] = df["Condition"].apply(to_nm)

for col in max_cols:
    plt.figure(figsize=(6,4))

    sns.scatterplot(
        data=df,
        x="Bolt_Nm",
        y=col,
        hue="Level"
    )

    plt.title(f"{col} vs Bolt Tightness (Level-wise)")
    plt.xlabel("Bolt Tightness (Nm)")
    plt.ylabel(col)
    plt.grid()

    plt.show()

# %%
df_melt = df.melt(
    id_vars=["Amplitude", "Level"],
    value_vars=max_cols,
    var_name="Sensor",
    value_name="MaxValue"
)

plt.figure(figsize=(8,5))

sns.scatterplot(
    data=df_melt,
    x="Amplitude",
    y="MaxValue",
    hue="Level",
    style="Sensor"
)

plt.title("Amplitude vs Vibration (Sensor + Level wise)")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

max_cols = [col for col in df.columns if "_max" in col]

for col in max_cols:
    plt.figure(figsize=(6,4))

    sns.lineplot(
        data=df,
        x="Amplitude",
        y=col,
        hue="Level",
        marker="o"
    )

    plt.title(f"{col} vs Amplitude (Level-wise)")
    plt.xlabel("Amplitude")
    plt.ylabel(col)
    plt.grid()

    plt.show()

# %%
def to_nm(cond):
    if cond == "Healthy":
        return 12
    elif "9" in cond:
        return 9
    elif "6" in cond:
        return 6
    else:
        return 0

df["Bolt_Nm"] = df["Condition"].apply(to_nm)

for col in max_cols:
    plt.figure(figsize=(6,4))

    sns.lineplot(
        data=df,
        x="Bolt_Nm",
        y=col,
        hue="Level",
        marker="o"
    )

    plt.title(f"{col} vs Bolt Tightness (Level-wise)")
    plt.xlabel("Bolt Tightness (Nm)")
    plt.ylabel(col)
    plt.grid()

    plt.show()

# %%
rms_cols = [col for col in df.columns if "_rms" in col]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

for col in rms_cols:
    plt.figure(figsize=(6,4))

    sns.lineplot(
        data=df,
        x="Amplitude",
        y=col,
        hue="Level",
        estimator=None,   # 🔥 IMPORTANT (no averaging)
        units="FileName", # each experiment separate line
        alpha=0.5
    )

    plt.title(f"{col} vs Amplitude (Raw, No Averaging)")
    plt.xlabel("Amplitude")
    plt.ylabel(col)
    plt.grid()

    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Ensure numeric
df["Amplitude"] = pd.to_numeric(df["Amplitude"], errors="coerce")

for col in rms_cols:
    df[col] = pd.to_numeric(df[col], errors="coerce")

# Drop NaN
df = df.dropna(subset=["Amplitude"] + rms_cols)

# Sort
df = df.sort_values(by="Amplitude")

# Plot
for col in rms_cols:
    plt.figure(figsize=(6,4))

    sns.lineplot(
        data=df,
        x="Amplitude",
        y=col,
        hue="Level",
        estimator=None,
        alpha=0.5
    )

    plt.title(f"{col} vs Amplitude")
    plt.grid()

    plt.show()
